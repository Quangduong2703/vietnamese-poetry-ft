# %% [markdown]
# # Qwen2.5-1.5B QLoRA on Colab
#
# This notebook mounts Google Drive, clones the repo, installs dependencies, and runs training with the Colab config.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/Quangduong2703/vietnamese-poetry-ft.git /content/vietnamese-poetry-ft || true
# %cd /content/vietnamese-poetry-ft
# !git pull

# %%
import torch
NPROC = torch.cuda.device_count()
print('Detected GPUs:', NPROC)
if NPROC < 1:
    raise RuntimeError('No GPU detected. Enable GPU in Runtime settings.')

# %%
# !pip install -r /content/vietnamese-poetry-ft/Source/requirements_qwen25_qlora.txt

# %%
# !torchrun --standalone --nproc_per_node={NPROC} /content/vietnamese-poetry-ft/Source/scripts/train_qwen25_15b_qlora.py \
  --config /content/vietnamese-poetry-ft/Source/configs/qwen25_15b_qlora_colab.json

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/drive/MyDrive/NLP/outputs/qwen25_15b_poetry_run1/runs
